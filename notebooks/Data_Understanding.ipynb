# %%
import pandas as pd

train = pd.read_csv('rossmann-store-sales/train.csv')
store = pd.read_csv('rossmann-store-sales/store.csv')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7320\1043381686.py:3: DtypeWarning: Columns (0: StateHoliday) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv('rossmann-store-sales/train.csv')

# %%
print('Train shape:', train.shape)
# Out:
# Train shape: (1017209, 9)

# %%
print('Train size:', train.size)
# Out:
# Train size: 9154881

# %%
print('Train info:', train.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  str
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(1), str(1)
# memory usage: 69.8+ MB
# Train info: None

# %%
print('Train describe:', train.describe())
# Out:
# Train describe:               Store     DayOfWeek         Sales     Customers          Open  \
# count  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# mean   5.584297e+02  3.998341e+00  5.773819e+03  6.331459e+02  8.301067e-01
# std    3.219087e+02  1.997391e+00  3.849926e+03  4.644117e+02  3.755392e-01
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.800000e+02  2.000000e+00  3.727000e+03  4.050000e+02  1.000000e+00
# 50%    5.580000e+02  4.000000e+00  5.744000e+03  6.090000e+02  1.000000e+00
# 75%    8.380000e+02  6.000000e+00  7.856000e+03  8.370000e+02  1.000000e+00
# max    1.115000e+03  7.000000e+00  4.155100e+04  7.388000e+03  1.000000e+00
#
#               Promo  SchoolHoliday
# count  1.017209e+06   1.017209e+06
# mean   3.815145e-01   1.786467e-01
# std    4.857586e-01   3.830564e-01
# min    0.000000e+00   0.000000e+00
# 25%    0.000000e+00   0.000000e+00
# 50%    0.000000e+00   0.000000e+00
# ...

# %%
print('Train describe include:', train.describe(include='object'))
# Out:
# Train describe include:               Date StateHoliday
# count      1017209      1017209
# unique         942            5
# top     2015-07-31            0
# freq          1115       855087
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7320\3417051848.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   print('Train describe include:', train.describe(include='object'))

# %%
print('Train StateHoliday unique values:', train['StateHoliday'].unique())
# Out:
# Train StateHoliday unique values: ['0' 'a' 'b' 'c' 0]

# %%
print('Train duplicated rows:', train.duplicated().sum())
# Out:
# Train duplicated rows: 0

# %%
print('Train dtypes:', train.dtypes)
# Out:
# Train dtypes: Store             int64
# DayOfWeek         int64
# Date                str
# Sales             int64
# Customers         int64
# Open              int64
# Promo             int64
# StateHoliday     object
# SchoolHoliday     int64
# dtype: object

# %%
print('Train null values:', train.isnull().sum())
# Out:
# Train null values: Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
print('Train Date min:', train['Date'].min())
print('Train Date max:', train['Date'].max())
# Out:
# Train Date min: 2013-01-01
# Train Date max: 2015-07-31

# %%
print('Train Store unique values:', train['Store'].nunique())
print('Train Date unique values:', train['Date'].nunique())
# Out:
# Train Store unique values: 1115
# Train Date unique values: 942

# %%
print('Train StateHoliday value counts:', train['StateHoliday'].value_counts())
# Out:
# Train StateHoliday value counts: StateHoliday
# 0    855087
# 0    131072
# a     20260
# b      6690
# c      4100
# Name: count, dtype: int64

# %%
print('Train Open value counts:', train['Open'].value_counts())
# Out:
# Train Open value counts: Open
# 1    844392
# 0    172817
# Name: count, dtype: int64

# %%
print('Train Promo value counts:', train['Promo'].value_counts())
# Out:
# Train Promo value counts: Promo
# 0    629129
# 1    388080
# Name: count, dtype: int64

# %%
print('Train SchoolHoliday value counts:', train['SchoolHoliday'].value_counts())
# Out:
# Train SchoolHoliday value counts: SchoolHoliday
# 0    835488
# 1    181721
# Name: count, dtype: int64

# %%
print('Store shape:', store.shape)
# Out:
# Store shape: (1115, 10)

# %%
print('Store size:', store.size)
# Out:
# Store size: 11150

# %%
print('Store info:', store.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int64
#  1   StoreType                  1115 non-null   str
#  2   Assortment                 1115 non-null   str
#  3   CompetitionDistance        1112 non-null   float64
#  4   CompetitionOpenSinceMonth  761 non-null    float64
#  5   CompetitionOpenSinceYear   761 non-null    float64
#  6   Promo2                     1115 non-null   int64
#  7   Promo2SinceWeek            571 non-null    float64
#  8   Promo2SinceYear            571 non-null    float64
#  9   PromoInterval              571 non-null    str
# dtypes: float64(5), int64(2), str(3)
# memory usage: 87.2 KB
# Store info: None

# %%
print('Store Type unique values:', store['StoreType'].unique())
# Out:
# Store Type unique values: <StringArray>
# ['c', 'a', 'd', 'b']
# Length: 4, dtype: str

# %%
print('Store Assortment unique values:', store['Assortment'].unique())
# Out:
# Store Assortment unique values: <StringArray>
# ['a', 'c', 'b']
# Length: 3, dtype: str

# %%
print('Store Promo2 unique values:', store['Promo2'].unique())
# Out:
# Store Promo2 unique values: [0 1]

# %%
print('Store duplicated rows:', store.duplicated().sum())
# Out:
# Store duplicated rows: 0

# %%
print('Store dtypes:', store.dtypes)
# Out:
# Store dtypes: Store                          int64
# StoreType                        str
# Assortment                       str
# CompetitionDistance          float64
# CompetitionOpenSinceMonth    float64
# CompetitionOpenSinceYear     float64
# Promo2                         int64
# Promo2SinceWeek              float64
# Promo2SinceYear              float64
# PromoInterval                    str
# dtype: object

# %%
print('Store null values:', store.isnull().sum())
# Out:
# Store null values: Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %%
print('Store StoreType value counts:', store['StoreType'].value_counts())
# Out:
# Store StoreType value counts: StoreType
# a    602
# d    348
# c    148
# b     17
# Name: count, dtype: int64

# %%
print('Store Assortment value counts:', store['Assortment'].value_counts())
# Out:
# Store Assortment value counts: Assortment
# a    593
# c    513
# b      9
# Name: count, dtype: int64

# %%
print('Store Promo2 value counts:', store['Promo2'].value_counts())
# Out:
# Store Promo2 value counts: Promo2
# 1    571
# 0    544
# Name: count, dtype: int64
